# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
retail=pd.read_csv(r"C:\Users\LENOVO\Future intern\swiggy_sales_data.csv")
retail
# Out:
#            Date      Orders       GOV  Promo_Running Weather
# 0    2022-01-01  195.000000  47865.57              0   Sunny
# 1    2022-01-02  210.258560  64907.26              1   Sunny
# 2    2022-01-03  184.517077  51486.67              0   Rainy
# 3    2022-01-04  204.775507  46629.14              0   Sunny
# 4    2022-01-05  217.033808  43865.97              0  Cloudy
# ..          ...         ...       ...            ...     ...
# 725  2023-12-27  195.033808  58743.89              0   Sunny
# 726  2023-12-28  192.775507  52625.61              0   Rainy
# 727  2023-12-29  197.517077  51935.90              0   Sunny
# 728  2023-12-30  206.258560  58508.98              1   Rainy
# 729  2023-12-31  205.000000  48626.28              0   Rainy
#
# [730 rows x 5 columns]

# %%
retail.isnull().sum()
# Out:
# Date             0
# Orders           0
# GOV              0
# Promo_Running    0
# Weather          0
# dtype: int64

# %%
pip install prophet
# Out:
# ...
#   Using cached importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# ...
#    ---------------------------------------- 0.0/13.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/13.3 MB 7.2 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.8/13.3 MB 4.6 MB/s eta 0:00:03
#    ------ --------------------------------- 2.1/13.3 MB 4.5 MB/s eta 0:00:03
#    ------ --------------------------------- 2.1/13.3 MB 4.5 MB/s eta 0:00:03
#    ------ --------------------------------- 2.1/13.3 MB 4.5 MB/s eta 0:00:03
#    ------ --------------------------------- 2.1/13.3 MB 4.5 MB/s eta 0:00:03
#    ------ --------------------------------- 2.1/13.3 MB 4.5 MB/s eta 0:00:03
#    ------- -------------------------------- 2.6/13.3 MB 1.4 MB/s eta 0:00:08
#    ---------- ----------------------------- 3.4/13.3 MB 1.7 MB/s eta 0:00:06
#    ------------- -------------------------- 4.5/13.3 MB 2.0 MB/s eta 0:00:05
# ...

# %%
from prophet import Prophet

# %%
grp=retail[['Date','Orders']]
grp=grp.rename(columns={'Date':'ds','Orders':'y'})
grp
# Out:
#              ds           y
# 0    2022-01-01  195.000000
# 1    2022-01-02  210.258560
# 2    2022-01-03  184.517077
# 3    2022-01-04  204.775507
# 4    2022-01-05  217.033808
# ..          ...         ...
# 725  2023-12-27  195.033808
# 726  2023-12-28  192.775507
# 727  2023-12-29  197.517077
# 728  2023-12-30  206.258560
# 729  2023-12-31  205.000000
#
# [730 rows x 2 columns]

# %%
php=Prophet()
php.fit(grp)
# Out:
# 19:23:21 - cmdstanpy - INFO - Chain [1] start processing
# 19:23:22 - cmdstanpy - INFO - Chain [1] done processing

# %%
future = php.make_future_dataframe(periods=90)
forecast = php.predict(future)

forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].to_csv("swiggy_forecast_output.csv", index=False)
